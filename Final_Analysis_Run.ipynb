# %%
pip install pandas matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
! python scripts/final_analysis.py
# Out:
# Success! Generated 3 charts and the cleaned CSV in the 'results/' directory.
# Verified: 10 unique players exported to results/undervalued_players.csv.
