# %%
! python scripts/integrate_nba_data.py
# Out:
# The 'data' folder exists!
# --- Integration Complete ---
# Total Integrated Records: 347
# Output saved to: data/processed/integrated_nba_data.csv
# Database artifact: data/nba_project.db
